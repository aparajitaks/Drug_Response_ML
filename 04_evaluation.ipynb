# %% [markdown]
# <a href="https://colab.research.google.com/github/aparajitaks/Drug_Response_ML/blob/main/04_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles here:")
print(os.listdir())
# Out:
# Current working directory:
# /content
#
# Files here:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

BASE_PATH = "/content/drive/MyDrive/Drug-Response-ML/models"
os.makedirs(BASE_PATH, exist_ok=True)

print("models folder created in Drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# models folder created in Drive

# %%
import joblib

BASE_PATH = "/content/drive/MyDrive/Drug-Response-ML/models"

logreg_model = joblib.load(f"{BASE_PATH}/logreg_model.pkl")
X_test = joblib.load(f"{BASE_PATH}/X_test.pkl")
y_test = joblib.load(f"{BASE_PATH}/y_test.pkl")

print("Model and test data loaded successfully")
# Out:
# Model and test data loaded successfully

# %%
y_pred = logreg_model.predict(X_test)

print("Predictions generated")
# Out:
# Predictions generated

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average="weighted"))
print("Recall   :", recall_score(y_test, y_pred, average="weighted"))
print("F1 Score :", f1_score(y_test, y_pred, average="weighted"))
# Out:
# Accuracy : 0.5275149373445237
# Precision: 0.6243600281501501
# Recall   : 0.5275149373445237
# F1 Score : 0.5568153346907803

# %%
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.56      0.49     10715
#            1       0.20      0.35      0.25      6346
#            2       0.81      0.56      0.66     25952
#
#     accuracy                           0.53     43013
#    macro avg       0.48      0.49      0.47     43013
# weighted avg       0.62      0.53      0.56     43013

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
