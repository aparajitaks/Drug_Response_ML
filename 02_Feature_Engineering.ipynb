# %% [markdown]
# <a href="https://colab.research.google.com/github/aparajitaks/Drug_Response_ML/blob/main/02_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

clean_path = "/content/drive/MyDrive/Drug-Response-ML/data/processed/cleaned_data.csv"
df = pd.read_csv(clean_path)

df.head()
# Out:
# Mounted at /content/drive
#    uniqueID                  drugName                     condition  \
# 0    206461                 valsartan  left ventricular dysfunction
# 1     95260                guanfacine                          adhd
# 2     92703                    lybrel                 birth control
# 3    138000                ortho evra                 birth control
# 4     35696  buprenorphine / naloxone             opiate dependence
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# ...

# %%
# Convert numeric ratings into response categories
def map_response(rating):
    if rating <= 4:
        return 0   # Poor
    elif rating <= 7:
        return 1   # Neutral
    else:
        return 2   # Good

df["response_category"] = df["rating"].apply(map_response)

# Verify
df[["rating", "response_category"]].head()
# Out:
#    rating  response_category
# 0       9                  2
# 1       8                  2
# 2       5                  1
# 3       8                  2
# 4       9                  2

# %%
features = ["drugName", "condition", "usefulCount"]
target = "response_category"

X = df[features]
y = df[target]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (215063, 3)
# y shape: (215063,)

# %%
X_encoded = pd.get_dummies(X, columns=["drugName", "condition"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (172050, 4589)
# Test size: (43013, 4589)
